# %% [markdown]
# # Введение в машинное обучение, АБД
#
# ## НИУ ВШЭ, 2025-26 учебный год

# %% [markdown]
# # Домашнее задание 1. Библиотеки Numpy, Matplotlib, Seaborn

# %% [markdown]
# **Задание выполнил:
# Мумджи Эмиль**

# %% [markdown]
# ## Общая информация

# %% [markdown]
# __Внимание!__
#
# Домашнее задание выполняется самостоятельно. Не допускается помощь в решении домашнего задания от однокурсников или третьих лиц. «Похожие» решения считаются плагиатом, и все задействованные студенты — в том числе и те, у кого списали, — не могут получить за него больше 0 баллов. Использование в решении домашнего задания генеративных моделей (ChatGPT и так далее) за рамками справочной и образовательной информации для генерации кода задания — считается плагиатом, и такое домашнее задание оценивается в 0 баллов.

# %% [markdown]
# Каждое задание весит 0.5 или 1 балл (указано рядом с номером задания).

# %% [markdown]
# ## Раздел 1. Вычисления с помощью Numpy

# %% [markdown]
# ### Задание 1 (0.5 балла)

# %% [markdown]
# Создайте массив Numpy под названием `a` размером 5x2, то есть состоящий из 5 строк и 2 столбцов. Первый столбец должен содержать числа `1, 2, 3, 3, 1`, а второй - числа `6, 8, 11, 10, 7`.
# Будем считать, что каждый столбец - это признак, а строка - наблюдение. Затем найдите среднее значение по каждому признаку, используя метод `mean` массива Numpy.
# Результат запишите в массив `mean_a`, в нем должно быть 2 элемента.

# %%
a = np.array([
    [1, 6],
    [2, 8],
    [3, 11],
    [3, 10],
    [1, 7]])
mean_a = np.mean(a, axis=0)

print(a)
print(mean_a)
# Out:
# [[ 1  6]
#  [ 2  8]
#  [ 3 11]
#  [ 3 10]
#  [ 1  7]]
# [2.  8.4]

# %% [markdown]
# ### Задание 2 (0.5 балла)

# %% [markdown]
# Вычислите массив `a_centered`, отняв от значений массива `а` средние значения соответствующих признаков, содержащиеся в массиве `mean_a`.
# Вычисление должно производиться в одно действие. Получившийся массив должен иметь размер 5x2.

# %%
a_centered = a - mean_a
print(a_centered)
# Out:
# [[-1.  -2.4]
#  [ 0.  -0.4]
#  [ 1.   2.6]
#  [ 1.   1.6]
#  [-1.  -1.4]]

# %% [markdown]
# ### Задание 3 (0.5 балла)

# %% [markdown]
# Найдите скалярное произведение столбцов массива `a_centered`. В результате должна получиться величина `a_centered_sp`.
# Затем поделите `a_centered_sp` на `N-1`, где `N` - число наблюдений.

# %%
a_centered_sp = np.dot(a_centered[:, 0], a_centered[:, 1])
N = len(a_centered)
print(a_centered_sp)
print(a_centered_sp / (N - 1))
# Out:
# 8.0
# 2.0

# %% [markdown]
# ### Задание 4 (0.5 балла)

# %% [markdown]
# Число, которое мы получили в конце задания 3 является ковариацией двух признаков, содержащихся в массиве `а`. В задании 3 мы делили сумму произведений центрированных признаков на `N-1`, а не на `N`, поэтому полученная нами величина является несмещенной оценкой ковариации.
#
# В этом задании проверьте получившееся число, вычислив ковариацию еще одним способом - с помощью функции `np.cov`. В качестве аргумента `m` функция `np.cov` должна принимать транспонированный массив `a`. В получившейся ковариационной матрице (массив Numpy размером 2x2) искомое значение ковариации будет равно элементу в строке с индексом 0 и столбце с индексом 1.

# %% [markdown]
# Примечание:
#
# Ковариация — это мера линейной зависимости между двумя случайными величинами. Она показывает, как переменные изменяются вместе: если при увеличении одной переменной другая также имеет тенденцию к увеличению, ковариация положительна; если при увеличении одной другой имеет тенденцию к уменьшению — отрицательна. Если ковариация равна нулю, это означает отсутствие линейной зависимости между переменными.
#
# Ковариация также является основой для более сложных статистических понятий, таких как корреляция, которая нормализует ковариацию, делая её независимой от масштабов измерений. Это позволяет более наглядно оценивать степень связи между переменными. Важно отметить, что ковариация не указывает на причинно-следственную связь, а лишь показывает, как две величины могут изменяться одновременно. Таким образом, ковариация является мощным инструментом для анализа взаимосвязей в данных и играет ключевую роль в статистическом моделировании и машинном обучении.

# %%
cov = np.cov(a.T)
print(cov[0, 1])
# Out:
# 2.0

# %% [markdown]
# ## Раздел 2. Работа с данными в Pandas

# %% [markdown]
# ### Задание 5 (0.5 балла)

# %% [markdown]
# Создайте датафрейм `authors` со столбцами `author_id` и `author_name`, в которых соответственно содержатся данные:
# `[1, 2, 3],
# ['Тургенев', 'Чехов', 'Островский']`.
#
# Затем создайте датафрейм `books` cо столбцами `author_id`, `book_title` и `price`, в которых соответственно содержатся данные:
# `[1, 1, 1, 2, 2, 3, 3],
# ['Отцы и дети', 'Рудин', 'Дворянское гнездо', 'Толстый и тонкий', 'Дама с собачкой', 'Гроза', 'Таланты и поклонники'],
# [450, 300, 350, 500, 450, 370, 290]`.

# %%
aut = {"author_id": [1, 2, 3], "author_name": ['Тургенев', 'Чехов', 'Островский']}
authors = pd.DataFrame(data=aut)
b = {"author_id": [1, 1, 1, 2, 2, 3, 3], "book_title": ['Отцы и дети', 'Рудин', 'Дворянское гнездо', 'Толстый и тонкий', 'Дама с собачкой', 'Гроза', 'Таланты и поклонники'], "price": [450, 300, 350, 500, 450, 370, 290]}
books = pd.DataFrame(data=b)

# %%
authors
# Out:
#    author_id author_name
# 0          1    Тургенев
# 1          2       Чехов
# 2          3  Островский

# %%
books
# Out:
#    author_id            book_title  price
# 0          1           Отцы и дети    450
# 1          1                 Рудин    300
# 2          1     Дворянское гнездо    350
# 3          2      Толстый и тонкий    500
# 4          2       Дама с собачкой    450
# 5          3                 Гроза    370
# 6          3  Таланты и поклонники    290

# %% [markdown]
# ### Задание 6 (0.5 балла)

# %% [markdown]
# Получите датафрейм `authors_price`, соединив датафреймы `authors` и `books` по полю `author_id`.

# %%
authors_price = pd.merge(books, authors, how="left", on="author_id")

# %%
authors_price
# Out:
#    author_id            book_title  price author_name
# 0          1           Отцы и дети    450    Тургенев
# 1          1                 Рудин    300    Тургенев
# 2          1     Дворянское гнездо    350    Тургенев
# 3          2      Толстый и тонкий    500       Чехов
# 4          2       Дама с собачкой    450       Чехов
# 5          3                 Гроза    370  Островский
# 6          3  Таланты и поклонники    290  Островский

# %% [markdown]
# ### Задание 7 (0.5 балла)

# %% [markdown]
# Создайте датафрейм `top5`, в котором содержатся строки из `authors_price` с пятью самыми дорогими книгами.

# %%
top5 = authors_price.sort_values(by="price", ascending=False).head()

# %%
top5
# Out:
#    author_id         book_title  price author_name
# 3          2   Толстый и тонкий    500       Чехов
# 4          2    Дама с собачкой    450       Чехов
# 0          1        Отцы и дети    450    Тургенев
# 5          3              Гроза    370  Островский
# 2          1  Дворянское гнездо    350    Тургенев

# %% [markdown]
# ### Задание 8 (0.5 балла)

# %% [markdown]
# Создайте датафрейм `authors_stat` на основе информации из `authors_price`.
# В датафрейме `authors_stat` должны быть четыре столбца:
# `author_name`, `min_price`, `max_price` и `mean_price`,
# в которых должны содержаться соответственно имя автора, минимальная, максимальная и средняя цена на книги этого автора.

# %%
authors_price
# Out:
#    author_id            book_title  price author_name
# 0          1           Отцы и дети    450    Тургенев
# 1          1                 Рудин    300    Тургенев
# 2          1     Дворянское гнездо    350    Тургенев
# 3          2      Толстый и тонкий    500       Чехов
# 4          2       Дама с собачкой    450       Чехов
# 5          3                 Гроза    370  Островский
# 6          3  Таланты и поклонники    290  Островский

# %%
authors_stat = authors_price.groupby("author_name").agg(min_price=("price", "min"), max_price=("price", "max"), mean_price=("price", "mean")).reset_index()

# %%
authors_stat
# Out:
#   author_name  min_price  max_price  mean_price
# 0  Островский        290        370  330.000000
# 1    Тургенев        300        450  366.666667
# 2       Чехов        450        500  475.000000

# %% [markdown]
# ### Задание 9 (1 балл)

# %% [markdown]
# Создайте новый столбец в датафрейме `authors_price` под названием `cover`, в нем будут располагаться данные о том, какая обложка у данной книги - твердая или мягкая. В этот столбец поместите данные из следующего списка:
# `['твердая', 'мягкая', 'мягкая', 'твердая', 'твердая', 'мягкая', 'мягкая']`.
#
# Просмотрите документацию по функции `pd.pivot_table` с помощью вопросительного знака. Для каждого автора посчитайте суммарную стоимость книг в твердой и мягкой обложке. Используйте для этого функцию `pd.pivot_table`. При этом столбцы должны называться "твердая" и "мягкая", а индексами должны быть фамилии авторов. Пропущенные значения стоимостей заполните нулями, при необходимости загрузите библиотеку Numpy.
#
# Назовите полученный датасет `book_info` и сохраните его в формат `pickle` под названием **book_info.pkl**. Затем загрузите из этого файла датафрейм и назовите его `book_info2`. Удостоверьтесь, что датафреймы `book_info` и `book_info2` идентичны.

# %%
# ?pd.pivot_table

# %%
authors_price["cover"] = pd.Series(['твердая', 'мягкая', 'мягкая', 'твердая', 'твердая', 'мягкая', 'мягкая'])

# %%
authors_price
# Out:
#    author_id            book_title  price author_name    cover
# 0          1           Отцы и дети    450    Тургенев  твердая
# 1          1                 Рудин    300    Тургенев   мягкая
# 2          1     Дворянское гнездо    350    Тургенев   мягкая
# 3          2      Толстый и тонкий    500       Чехов  твердая
# 4          2       Дама с собачкой    450       Чехов  твердая
# 5          3                 Гроза    370  Островский   мягкая
# 6          3  Таланты и поклонники    290  Островский   мягкая

# %%
book_info = pd.pivot_table(data=authors_price, values="price", index="author_name", columns="cover", aggfunc="sum", fill_value=0)

# %%
book_info
# Out:
# cover        мягкая  твердая
# author_name
# Островский      660        0
# Тургенев        650      450
# Чехов             0      950

# %%
book_info.to_pickle("book_info.pkl")

# %%
book_info2 = pd.read_pickle("book_info.pkl")

# %%
book_info2
# Out:
# cover        мягкая  твердая
# author_name
# Островский      660        0
# Тургенев        650      450
# Чехов             0      950

# %% [markdown]
# ## Раздел 3. Библиотека Matplotlib

# %% [markdown]
# ### Задание 10 (0.5 балла)

# %% [markdown]
# Создайте список под названием x с числами `1, 2, 3, 4, 5, 6, 7` и список y с числами `3.5, 3.8, 4.2, 4.5, 5, 5.5, 7`.
#
# С помощью функции `plot` постройте график, соединяющий линиями точки с горизонтальными координатами из списка `x` и вертикальными - из списка `y`.
#
# Затем в следующей ячейке постройте диаграмму рассеяния (другие названия - диаграмма разброса, *scatter plot*).

# %%
x = [1, 2, 3, 4, 5, 6, 7]
y = [3.5, 3.8, 4.2, 4.5, 5, 5.5, 7]
plt.plot(x, y)
plt.show()

# %%
plt.scatter(x, y)
plt.show()

# %% [markdown]
# ### Задание 11 (0.5 балла)

# %% [markdown]
# - С помощью функции `linspace` из библиотеки *Numpy* создайте массив `t` из 51  числа от 0 до 10 включительно.
# - Создайте массив Numpy под названием `f`, содержащий косинусы элементов массива t.
# - Постройте линейную диаграмму, используя массив `t` для координат по горизонтали,а массив `f` - для координат по вертикали. Линия графика должна быть зеленого цвета.
# - Выведите название диаграммы - *График f(t)*.
# - Также добавьте названия для горизонтальной оси - *Значения t* и для вертикальной - *Значения f*.
# - Ограничьте график по оси `x` значениями 0.5 и 9.5, а по оси `y` - значениями -2.5 и 2.5.

# %%
t = np.linspace(0, 10, 51)
f = np.cos(t)
plt.title("График f(t)")
plt.xlabel("Значения t")
plt.ylabel("Значения f")
plt.plot(t, f, color="green")
plt.xlim(0.5, 9.5)
plt.ylim(-2.5, 2.5)
plt.show()

# %% [markdown]
# ### Задание 12 (0.5 балла)

# %% [markdown]
# - С помощью функции `linspace` библиотеки Numpy создайте массив `x` из 51 числа от -3 до 3 включительно.
#
# - Создайте массивы `y1`, `y2`, `y3`, `y4` по следующим формулам:
#   - y1 = x**2
#   - y2 = 2 * x + 0.5
#   - y3 = -3 * x - 1.5
#   - y4 = sin(x)
#
# - Используя функцию `subplots` модуля `matplotlib.pyplot`, создайте объект `matplotlib.figure.Figure` с названием *fig* и массив объектов `Axes` под названием *ax*, причем так, чтобы у вас было *4* отдельных графика в сетке, состоящей из двух строк и двух столбцов.
#
# - В каждом графике массив `x` используется для координат по горизонтали.
# В левом верхнем графике для координат по вертикали используйте `y1`,
# в правом верхнем - `y2`, в левом нижнем - `y3`, в правом нижнем - `y4`.
# - Дайте название графикам: *График y1*, *График y2* и т.д.
# - Для графика в левом верхнем углу установите границы по оси *x* от *-5* до *5*.
# - Установите размеры фигуры *8* дюймов по горизонтали и 6 дюймов по вертикали.
# Вертикальные и горизонтальные зазоры между графиками должны составлять *0.3*.

# %%
x = np.linspace(-3, 3, 51)
y1 = x**2
y2 = 2*x + 0.5
y3 = -3*x - 1.5
y4 = np.sin(x)
fig, ax = plt.subplots(2, 2, figsize=(8, 6))

ax[0, 0].plot(x, y1)
ax[0, 0].set_title("График y1")
ax[0, 0].set_xlim(-5, 5)

ax[0, 1].plot(x, y2)
ax[0, 1].set_title("График y2")

ax[1, 0].plot(x, y3)
ax[1, 0].set_title("График y3")

ax[1, 1].plot(x, y4)
ax[1, 1].set_title("График y4")

plt.subplots_adjust(hspace=0.3, wspace=0.3)
plt.show()

# %% [markdown]
# ### Задание 13 (0.5 балла)

# %% [markdown]
# В этом задании мы будем работать с датасетом, в котором приведены данные по мошенничеству с кредитными данными: Credit Card Fraud Detection (информация об авторах: Andrea Dal Pozzolo, Olivier Caelen, Reid A. Johnson and Gianluca Bontempi. Calibrating Probability with Undersampling for Unbalanced Classification. In Symposium on Computational Intelligence and Data Mining (CIDM), IEEE, 2015).
#
# Данный датасет является примером несбалансированных данных, так как мошеннические операции с картами встречаются реже обычных.
# Импортруйте библиотеку `Pandas`, а также используйте для графиков стиль *fivethirtyeight*.
#
# Посчитайте с помощью метода `value_counts` количество наблюдений для каждого значения целевой переменной `Class` и примените к полученным данным метод `plot`, чтобы построить столбчатую диаграмму. Затем постройте такую же диаграмму, используя логарифмический масштаб.
#
# На следующем графике постройте две гистограммы по значениям признака `V1` - одну для мошеннических транзакций (`Class` равен *1*) и другую - для обычных (`Class` равен *0*). Подберите значение аргумента `density` так, чтобы по вертикали графика было расположено не число наблюдений, а плотность распределения. Число бинов должно равняться *20* для обеих гистограмм, а коэффициент `alpha` сделайте равным *0.5*, чтобы гистограммы были полупрозрачными и не загораживали друг друга. Создайте легенду с двумя значениями: *Class 0* и *Class 1*. Гистограмма обычных транзакций должна быть серого цвета, а мошеннических - красного. Горизонтальной оси дайте название *Class*.

# %%
CREDIT_CARDS = 'https://www.dropbox.com/scl/fi/52uguzbixqi73kt3wlfy0/creditcard.csv?rlkey=l81ujgqku690hxcz72nz1ihi3&st=c7jd71e5&dl=1'

# %%
df = pd.read_csv(CREDIT_CARDS)

# %%
df
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 0       0.462388  0.239599  0.098698  0.363787  ... -0.018307  0.277838
# 1      -0.082361 -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672
# 2       1.800499  0.791461  0.247676 -1.514654  ...  0.247998  0.771679
# 3       1.247203  0.237609  0.377436 -1.387024  ... -0.108300  0.005274
# 4       0.095921  0.592941 -0.270533  0.817739  ... -0.009431  0.798278
# ...          ...       ...       ...       ...  ...       ...       ...
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# 0      -0.110474  0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62
# 1       0.101288 -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69
# 2       0.909412 -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66
# 3      -0.190321 -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50
# 4      -0.137458  0.141267 -0.206010  0.502292  0.219422  0.215153   69.99
# ...          ...       ...       ...       ...       ...       ...     ...
# 284802  1.014480 -0.509348  1.436807  0.250034  0.943651  0.823731    0.77
# 284803  0.012463 -1.016226 -0.606624 -0.395255  0.068472 -0.053527   24.79
# 284804 -0.037501  0.640134  0.265745 -0.087371  0.004455 -0.026561   67.88
# 284805 -0.163298  0.123205 -0.569159  0.546668  0.108821  0.104533   10.00
# 284806  0.376777  0.008797 -0.473649 -0.818267 -0.002415  0.013649  217.00
#
#         Class
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 284802      0
# 284803      0
# 284804      0
# 284805      0
# 284806      0
#
# [284807 rows x 31 columns]

# %%
plt.style.use("fivethirtyeight")
df.Class.value_counts().plot(kind='bar')
plt.show()

# %%
plt.style.use("fivethirtyeight")
df.Class.value_counts().plot(kind="bar", logy=True)
plt.show()

# %%
fraud = df.query("Class == 1").V1
usual = df.query("Class == 0").V1

# %%
plt.style.use("fivethirtyeight")
plt.hist(usual, bins=20, density=True, alpha=0.5, color="gray", label="Class 0")
plt.hist(fraud, bins=20, density=True, alpha=0.5, color="red", label="Class 1")
plt.xlabel("Class")
plt.legend()
plt.show()

# %% [markdown]
# ## Раздел 4. Визуализации в датасете кредитного скоринга

# %% [markdown]
# ### О задании

# %% [markdown]
# Вы будете работать с задачей кредитного скоринга (оценка надёжности клиента). Предоставляются данные о 1000 клиентов, про которых известно около 20 признаков и положительная или отрицательная оценка в качестве кредитуемого. Эти данные нужно исследовать с помощью средств визуализации.
#
# *Описание данных*:
# https://www.rdocumentation.org/packages/evtree/versions/1.0-8/topics/GermanCredit
#
# Каждый построенный график необходимо красиво оформить – для этого требуется как минимум указать его название, а также отметить, что изображено по каждой из осей.
# **Также по каждому графику ожидается небольшой комментарий с выводами.**
#
# *Функции, которые могут пригодиться при оформлении графиков: `.show()`, `.title()`, `.xlabel()`, `.ylabel()`*

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
GERMAN_CREDIT = 'https://github.com/evgpat/datasets/raw/refs/heads/main/german_credit.csv'

# %%
df = pd.read_csv(GERMAN_CREDIT)
df
# Out:
#                                          status  duration  \
# 0                           no checking account        18
# 1                           no checking account         9
# 2                                    ... < 0 DM        12
# 3                           no checking account        12
# 4                           no checking account        12
# ..                                          ...       ...
# 995                         no checking account        24
# 996                         no checking account        24
# 997  ... >= 200 DM / salary for at least 1 year        21
# 998                                  ... < 0 DM        12
# 999                         no checking account        30
#
#                                   credit_history              purpose  amount  \
# 0        all credits at this bank paid back duly           car (used)    1049
# 1        all credits at this bank paid back duly               others    2799
# 2    no credits taken/all credits paid back duly           retraining     841
# 3        all credits at this bank paid back duly               others    2122
# 4        all credits at this bank paid back duly               others    2171
# ..                                           ...                  ...     ...
# 995  no credits taken/all credits paid back duly  furniture/equipment    1987
# 996  no credits taken/all credits paid back duly               others    2303
# 997      all credits at this bank paid back duly               others   12680
# 998  no credits taken/all credits paid back duly  furniture/equipment    6468
# 999  no credits taken/all credits paid back duly           car (used)    6350
#
#                         savings employment_duration installment_rate  \
# 0    unknown/no savings account              < 1 yr             < 20
# 1    unknown/no savings account    1 <= ... < 4 yrs   25 <= ... < 35
# 2                 ... <  100 DM    4 <= ... < 7 yrs   25 <= ... < 35
# 3    unknown/no savings account    1 <= ... < 4 yrs   20 <= ... < 25
# 4    unknown/no savings account    1 <= ... < 4 yrs             < 20
# ..                          ...                 ...              ...
# 995  unknown/no savings account    1 <= ... < 4 yrs   25 <= ... < 35
# 996  unknown/no savings account            >= 7 yrs             < 20
# 997              ... >= 1000 DM            >= 7 yrs             < 20
# 998              ... >= 1000 DM          unemployed   25 <= ... < 35
# 999              ... >= 1000 DM            >= 7 yrs             < 20
#
#                       personal_status_sex other_debtors  ...  \
# 0    female : non-single or male : single          none  ...
# 1                  male : married/widowed          none  ...
# 2    female : non-single or male : single          none  ...
# 3                  male : married/widowed          none  ...
# 4                  male : married/widowed          none  ...
# ..                                    ...           ...  ...
# 995                male : married/widowed          none  ...
# 996                male : married/widowed  co-applicant  ...
# 997                male : married/widowed          none  ...
# 998                male : married/widowed          none  ...
# 999                male : married/widowed          none  ...
#
#                   property age  other_installment_plans   housing  \
# 0             car or other  21                     none  for free
# 1    unknown / no property  36                     none  for free
# 2    unknown / no property  23                     none  for free
# 3    unknown / no property  39                     none  for free
# 4             car or other  38                     bank      rent
# ..                     ...  ..                      ...       ...
# 995  unknown / no property  21                     none  for free
# 996  unknown / no property  45                     none      rent
# 997            real estate  30                     none       own
# 998            real estate  52                     none      rent
# 999           car or other  31                     none      rent
#
#     number_credits                                         job people_liable  \
# 0                1                   skilled employee/official        0 to 2
# 1              2-3                   skilled employee/official     3 or more
# 2                1                        unskilled - resident        0 to 2
# 3              2-3                        unskilled - resident     3 or more
# 4              2-3                        unskilled - resident        0 to 2
# ..             ...                                         ...           ...
# 995              1                        unskilled - resident     3 or more
# 996              1                   skilled employee/official        0 to 2
# 997              1  manager/self-empl./highly qualif. employee        0 to 2
# 998              1  manager/self-empl./highly qualif. employee        0 to 2
# 999              1                   skilled employee/official        0 to 2
#
#                      telephone foreign_worker credit_risk
# 0                           no             no        good
# 1                           no             no        good
# 2                           no             no        good
# 3                           no            yes        good
# 4                           no            yes        good
# ..                         ...            ...         ...
# 995                         no             no         bad
# 996                         no             no         bad
# 997  yes (under customer name)             no         bad
# 998  yes (under customer name)             no         bad
# 999                         no             no         bad
#
# [1000 rows x 21 columns]

# %%
import seaborn as sns

# %%
GERMAN_CREDIT = 'https://github.com/evgpat/datasets/raw/refs/heads/main/german_credit.csv'

# %% [markdown]
# ### Задание 14 (0.5 балла)

# %% [markdown]
# Используя `numpy` и `matplotlib`, начнём с тренировки: постройте график функций $sin(x)$ и $cos(x)$ на интервале от $-\pi$ до $\pi$, используя 100 точек. Добавьте легенду и сетку. Используйте для линий разные цвета, одна из них пусть будет пунктирной. Результат в этом и следующих заданиях на построение графиков должен получиться максимально схожим с картинкой. Содержание подписей не должно обязательно совпадать, однако осмысленные подписи должны присутствовать на графиках.

# %%
x = np.linspace(-np.pi, np.pi, 100)
sin = np.sin(x)
cos = np.cos(x)

plt.figure(figsize=(6, 4))

plt.plot(x, sin, label='y=sin(x)', color = 'mediumturquoise')
plt.plot(x, cos, label='y=cos(x)', color = 'mediumorchid', linestyle='--')

plt.title('Графики sin(x) и cos(x)')
plt.xlabel('x')
plt.ylabel('y')

plt.legend()
plt.grid(True)

# %%
|# то что должно получиться

# %% [markdown]
# ### Задание 15 (0.5 балла)

# %% [markdown]
# Прочитайте средствами pandas файл с данными кредитного скоринга. Рассмотрите сравнительное количество положительных и отрицательных кейсов в зависимости от размера текущего счёта. Постройте зеркальные горизонтальные гистограммы.

# %%
df
# Out:
#                                          status  duration  \
# 0                           no checking account        18
# 1                           no checking account         9
# 2                                    ... < 0 DM        12
# 3                           no checking account        12
# 4                           no checking account        12
# ..                                          ...       ...
# 995                         no checking account        24
# 996                         no checking account        24
# 997  ... >= 200 DM / salary for at least 1 year        21
# 998                                  ... < 0 DM        12
# 999                         no checking account        30
#
#                                   credit_history              purpose  amount  \
# 0        all credits at this bank paid back duly           car (used)    1049
# 1        all credits at this bank paid back duly               others    2799
# 2    no credits taken/all credits paid back duly           retraining     841
# 3        all credits at this bank paid back duly               others    2122
# 4        all credits at this bank paid back duly               others    2171
# ..                                           ...                  ...     ...
# 995  no credits taken/all credits paid back duly  furniture/equipment    1987
# 996  no credits taken/all credits paid back duly               others    2303
# 997      all credits at this bank paid back duly               others   12680
# 998  no credits taken/all credits paid back duly  furniture/equipment    6468
# 999  no credits taken/all credits paid back duly           car (used)    6350
#
#                         savings employment_duration installment_rate  \
# 0    unknown/no savings account              < 1 yr             < 20
# 1    unknown/no savings account    1 <= ... < 4 yrs   25 <= ... < 35
# 2                 ... <  100 DM    4 <= ... < 7 yrs   25 <= ... < 35
# 3    unknown/no savings account    1 <= ... < 4 yrs   20 <= ... < 25
# 4    unknown/no savings account    1 <= ... < 4 yrs             < 20
# ..                          ...                 ...              ...
# 995  unknown/no savings account    1 <= ... < 4 yrs   25 <= ... < 35
# 996  unknown/no savings account            >= 7 yrs             < 20
# 997              ... >= 1000 DM            >= 7 yrs             < 20
# 998              ... >= 1000 DM          unemployed   25 <= ... < 35
# 999              ... >= 1000 DM            >= 7 yrs             < 20
#
#                       personal_status_sex other_debtors  ...  \
# 0    female : non-single or male : single          none  ...
# 1                  male : married/widowed          none  ...
# 2    female : non-single or male : single          none  ...
# 3                  male : married/widowed          none  ...
# 4                  male : married/widowed          none  ...
# ..                                    ...           ...  ...
# 995                male : married/widowed          none  ...
# 996                male : married/widowed  co-applicant  ...
# 997                male : married/widowed          none  ...
# 998                male : married/widowed          none  ...
# 999                male : married/widowed          none  ...
#
#                   property age  other_installment_plans   housing  \
# 0             car or other  21                     none  for free
# 1    unknown / no property  36                     none  for free
# 2    unknown / no property  23                     none  for free
# 3    unknown / no property  39                     none  for free
# 4             car or other  38                     bank      rent
# ..                     ...  ..                      ...       ...
# 995  unknown / no property  21                     none  for free
# 996  unknown / no property  45                     none      rent
# 997            real estate  30                     none       own
# 998            real estate  52                     none      rent
# 999           car or other  31                     none      rent
#
#     number_credits                                         job people_liable  \
# 0                1                   skilled employee/official        0 to 2
# 1              2-3                   skilled employee/official     3 or more
# 2                1                        unskilled - resident        0 to 2
# 3              2-3                        unskilled - resident     3 or more
# 4              2-3                        unskilled - resident        0 to 2
# ..             ...                                         ...           ...
# 995              1                        unskilled - resident     3 or more
# 996              1                   skilled employee/official        0 to 2
# 997              1  manager/self-empl./highly qualif. employee        0 to 2
# 998              1  manager/self-empl./highly qualif. employee        0 to 2
# 999              1                   skilled employee/official        0 to 2
#
#                      telephone foreign_worker credit_risk
# 0                           no             no        good
# 1                           no             no        good
# 2                           no             no        good
# 3                           no            yes        good
# 4                           no            yes        good
# ..                         ...            ...         ...
# 995                         no             no         bad
# 996                         no             no         bad
# 997  yes (under customer name)             no         bad
# 998  yes (under customer name)             no         bad
# 999                         no             no         bad
#
# [1000 rows x 21 columns]

# %%
good_risk = df.query("credit_risk == 'good'").status
bad_risk = df.query("credit_risk == 'bad'").status
good_risk.value_counts()
# Out:
# status
# ... >= 200 DM / salary for at least 1 year    348
# ... < 0 DM                                    164
# no checking account                           139
# 0<= ... < 200 DM                               49
# Name: count, dtype: int64

# %%
categories = ['no checking account','0<= ... < 200 DM','... >= 200 DM / salary for at least 1 year','... < 0 DM']

fig, axes = plt.subplots(1, 2, sharey=True, figsize=(12,6))
max_value = 360

good_counts = good_risk.value_counts().reindex(categories)
bad_counts = bad_risk.value_counts().reindex(categories)

axes[0].barh(categories, good_counts, color='green')
axes[0].set_xlim(max_value, 0)
axes[0].invert_yaxis()
axes[0].set_title("Good Risk")
axes[0].set_xlabel("Количество клиентов")

axes[1].barh(categories, bad_counts, color='red')
axes[1].set_xlim(0, max_value)
axes[1].set_title("Bad Risk")
axes[1].set_xlabel("Количество клиентов")

axes[1].tick_params(labelright=True)
axes[1].yaxis.set_ticks_position('right')

plt.subplots_adjust(wspace=0.05)
fig.suptitle("Status of checking account", fontsize=14)
plt.show()

# Клиенты с хорошим кредитным рейтингом чаще имеют более высокий баланс счёта (≥ 200 DM), тогда как среди клиентов с плохим рейтингом чаще встречаются категории с низким балансом или отсутствием счёта

# %%
# то что должно получиться

# %% [markdown]
# ### Задание 16 (0.5 балла)

# %%
import seaborn as sns

# %% [markdown]
# Теперь постройте гистограмму для сравнения количества положительных и отрицательных кейсов в зависимости от размера сберегательного счёта с помощью seaborn. Какой способ вам больше нравится с точки зрения трудоёмкости написания кода? А с точки зрения восприятия результата?

# %%
df
# Out:
#                                          status  duration  \
# 0                           no checking account        18
# 1                           no checking account         9
# 2                                    ... < 0 DM        12
# 3                           no checking account        12
# 4                           no checking account        12
# ..                                          ...       ...
# 995                         no checking account        24
# 996                         no checking account        24
# 997  ... >= 200 DM / salary for at least 1 year        21
# 998                                  ... < 0 DM        12
# 999                         no checking account        30
#
#                                   credit_history              purpose  amount  \
# 0        all credits at this bank paid back duly           car (used)    1049
# 1        all credits at this bank paid back duly               others    2799
# 2    no credits taken/all credits paid back duly           retraining     841
# 3        all credits at this bank paid back duly               others    2122
# 4        all credits at this bank paid back duly               others    2171
# ..                                           ...                  ...     ...
# 995  no credits taken/all credits paid back duly  furniture/equipment    1987
# 996  no credits taken/all credits paid back duly               others    2303
# 997      all credits at this bank paid back duly               others   12680
# 998  no credits taken/all credits paid back duly  furniture/equipment    6468
# 999  no credits taken/all credits paid back duly           car (used)    6350
#
#                         savings employment_duration installment_rate  \
# 0    unknown/no savings account              < 1 yr             < 20
# 1    unknown/no savings account    1 <= ... < 4 yrs   25 <= ... < 35
# 2                 ... <  100 DM    4 <= ... < 7 yrs   25 <= ... < 35
# 3    unknown/no savings account    1 <= ... < 4 yrs   20 <= ... < 25
# 4    unknown/no savings account    1 <= ... < 4 yrs             < 20
# ..                          ...                 ...              ...
# 995  unknown/no savings account    1 <= ... < 4 yrs   25 <= ... < 35
# 996  unknown/no savings account            >= 7 yrs             < 20
# 997              ... >= 1000 DM            >= 7 yrs             < 20
# 998              ... >= 1000 DM          unemployed   25 <= ... < 35
# 999              ... >= 1000 DM            >= 7 yrs             < 20
#
#                       personal_status_sex other_debtors  ...  \
# 0    female : non-single or male : single          none  ...
# 1                  male : married/widowed          none  ...
# 2    female : non-single or male : single          none  ...
# 3                  male : married/widowed          none  ...
# 4                  male : married/widowed          none  ...
# ..                                    ...           ...  ...
# 995                male : married/widowed          none  ...
# 996                male : married/widowed  co-applicant  ...
# 997                male : married/widowed          none  ...
# 998                male : married/widowed          none  ...
# 999                male : married/widowed          none  ...
#
#                   property age  other_installment_plans   housing  \
# 0             car or other  21                     none  for free
# 1    unknown / no property  36                     none  for free
# 2    unknown / no property  23                     none  for free
# 3    unknown / no property  39                     none  for free
# 4             car or other  38                     bank      rent
# ..                     ...  ..                      ...       ...
# 995  unknown / no property  21                     none  for free
# 996  unknown / no property  45                     none      rent
# 997            real estate  30                     none       own
# 998            real estate  52                     none      rent
# 999           car or other  31                     none      rent
#
#     number_credits                                         job people_liable  \
# 0                1                   skilled employee/official        0 to 2
# 1              2-3                   skilled employee/official     3 or more
# 2                1                        unskilled - resident        0 to 2
# 3              2-3                        unskilled - resident     3 or more
# 4              2-3                        unskilled - resident        0 to 2
# ..             ...                                         ...           ...
# 995              1                        unskilled - resident     3 or more
# 996              1                   skilled employee/official        0 to 2
# 997              1  manager/self-empl./highly qualif. employee        0 to 2
# 998              1  manager/self-empl./highly qualif. employee        0 to 2
# 999              1                   skilled employee/official        0 to 2
#
#                      telephone foreign_worker credit_risk
# 0                           no             no        good
# 1                           no             no        good
# 2                           no             no        good
# 3                           no            yes        good
# 4                           no            yes        good
# ..                         ...            ...         ...
# 995                         no             no         bad
# 996                         no             no         bad
# 997  yes (under customer name)             no         bad
# 998  yes (under customer name)             no         bad
# 999                         no             no         bad
#
# [1000 rows x 21 columns]

# %%
good_risk = df.query("credit_risk == 'good'").savings.value_counts()
bad_risk = df.query("credit_risk == 'bad'").savings.value_counts()

bad_risk
# Out:
# savings
# unknown/no savings account    217
# ... <  100 DM                  34
# ... >= 1000 DM                 32
# 100 <= ... <  500 DM           11
# 500 <= ... < 1000 DM            6
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10,6))

sns.countplot(data=df, x='savings', hue='credit_risk', palette={'good': 'green', 'bad': 'red'})

plt.title("Зависимость кредитного риска от уровня сбережений")
plt.xlabel("Уровень сбережений")
plt.ylabel("Количество клиентов")


plt.show()

# Наблюдается зависимость кредитного риска от уровня сбережений: чем выше сбережения, тем выше вероятность положительного кредитного рейтинга

# %%
# то что должно получиться

# %% [markdown]
# **ВАШ ОТВЕТ**
# Seabron сильно лучше, поскольку меньше кода, а следовательно писать быстрее. Не нужно вручную агрегировать данные и настраивать график

# %% [markdown]
# ### Задание 17 (0.5 балла)

# %% [markdown]
# seaborn легко позволяет добавить ещё больше информации на один график. Для каждого размера сберегательного счёта мы можем оценить не только количество положительных и отрицательных кейсов, но и их распределение по возрасту, например. Постройте подходящую для этого визуализацию.

# %%
plt.figure(figsize=(14,10))
violin = sns.violinplot(data=df, x='savings', y='age', hue='credit_risk', palette={'good': 'green', 'bad': 'red'}, split=True, inner=None)
plt.title("Распределение возраста клиентов по уровню сбережений и кредитному риску")
plt.xlabel("Уровень сбережений")
plt.ylabel("Возраст")

sns.boxplot(data=df, x='savings', y='age', width=0.03, showfliers=False, boxprops={'facecolor': '#333333', 'edgecolor': '#333333', 'linewidth': 0.4}, medianprops={'color': '#dddddd', 'linewidth': 0.8},)
plt.legend(loc='upper right', title='credit_risk')
plt.show()

# Возраст не является сильным фактором, влияющим на кредитный риск, в отличие от уровня сбережений

# %%
# то что должно получиться

# %% [markdown]
# ### Задание 18 (0.5 балла)

# %% [markdown]
# Заканчивая с гистограммами, посмотрим на распределение положительных и отрицательных кейсов по возрастам, разместив их друг над другом. Добавим распределение всех взятых кредитов.

# %%
good_age = df.query("credit_risk == 'good'")['age']
bad_age = df.query("credit_risk == 'bad'")['age']
all_age = df['age']

# %%
fig, axes = plt.subplots(3, 1, figsize=(8, 10), sharex=True)

ymax = 250

a = axes[0].hist(good_age, bins=11, color='green')
axes[0].set_title('Good credits age distribution')
axes[0].set_ylim(0, ymax)
axes[0].set_ylabel('Count')

b = axes[1].hist(bad_age, bins=11, color='red')
axes[1].set_title('Bad credits age distribution')
axes[1].set_ylim(0, ymax)
axes[1].set_ylabel('Count')

c = axes[2].hist(all_age, bins=11, color='steelblue')
axes[2].set_title('Overall age distribution')
axes[2].set_ylim(0, ymax)
axes[2].set_ylabel('Count')

for ax in axes:
    ax.set_xlabel('Age')
    ax.tick_params(labelbottom=True)

fig.legend([a[2][0], b[2][0], c[2][0]], ['Good credits age distribution', 'Bad credits age distribution', 'Overall age distribution'], loc='upper right', bbox_to_anchor=(0.98, 0.96))
plt.tight_layout()
plt.show()

# Большинство заемщиков в возрасте 25–40 лет. Молодые клиенты чаще имеют плохие кредиты,
# а с увеличением возраста доля плохих кредитов уменьшается

# %%
# то что должно получиться

# %% [markdown]
# ### Задание 19 (0.5 балла)

# %% [markdown]
# Не менее полезной иногда может быть диаграмма рассеяния. Постройте такую диаграмму с продолжительностью и размерами кредитов в качестве осей. Обозначьте положительные и отрицательные кейсы разными цветами.

# %%
plt.figure(figsize=(11,7))
sns.scatterplot(data=df, x='amount', y='duration', hue='credit_risk',palette=['green', 'red'], legend=False)

plt.xlabel('Credit amount')
plt.ylabel('Duration')
plt.title('Credits')
plt.show()

# Положительная зависимость между размером кредита и его продолжительностью. Более крупные кредиты выдаются на более длительный срок

# %%
# то что должно получиться

# %% [markdown]
# ### Задание 20* (1 балл)

# %%
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(df['amount'], df['duration'], df['age'], c=df['credit_risk'].map({'good': 'green', 'bad': 'red'}), s=20, alpha=0.7)

ax.set_xlabel('Credit amount')
ax.set_ylabel('Duration')

ax.tick_params(axis='z', pad=-1)
ax.set_zlabel('Age', labelpad=-4)

plt.tight_layout()
plt.show()

# %% [markdown]
# Продвинемся глубже. Постройте 3D версию диаграммы рассеяния, добавив ось с возрастом.

# %%
# то что должно получиться

# %% [markdown]
# Что вы можете сказать о сравнении 3D- и 2D-визуализаций? Какие вы видите в них преимущества и недостатки?
#
# Какие выводы с точки зрения бизнеса можно сделать из полученного графика?

# %% [markdown]
# **ВАШ ОТВЕТ**
# 3д график позволяет увидеть зависимость сразу между тремя переменными, но его сложнее воспринимать, 2д графики удобнее для анализа, так как по ним легче заметить закономерности
#
# С увеличением суммы кредита обычно увеличивается и срок. При этом более крупные и долгосрочные кредиты чаще связаны с повышенным риском. Возраст при этом не оказывает заметного влияния, так как хорошие и плохие клиенты по нему сильно перемешаны

# %% [markdown]
# ## Раздел 5. Визуализации в датасете Netflix

# %%
NETFLIX_TITLES = 'https://github.com/evgpat/datasets/raw/refs/heads/main/netflix_titles.csv'
data = pd.read_csv(NETFLIX_TITLES)

# %% [markdown]
# ### Задание 21  (0.5 балла)

# %% [markdown]
# Прочитайте средствами pandas файл с данными Netflix. Посчитайте количество пропусков (NaN) в колонке `director`. Постройте столбчатую диаграмму, которая показывает 5 стран, в которых наибольшее количество фильмов имеет пропуски в столбце director.
#
# Добавьте на диаграмму:
#
# - Заголовок жирным шрифтом
# - Подписи осей

# %%
data
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                NaN                                            Nasty C
# 7785                NaN                         Adriano Zumbo, Rachel Khoo
# 7786           Sam Dunn                                                NaN
#
#                                                 country          date_added  \
# 0                                                Brazil     August 14, 2020
# 1                                                Mexico   December 23, 2016
# 2                                             Singapore   December 20, 2018
# 3                                         United States   November 16, 2017
# 4                                         United States     January 1, 2020
# ...                                                 ...                 ...
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7783                                              India       March 2, 2019
# 7784                                                NaN  September 25, 2020
# 7785                                          Australia    October 31, 2020
# 7786              United Kingdom, Canada, United States       March 1, 2020
#
#       release_year rating   duration  \
# 0             2020  TV-MA  4 Seasons
# 1             2016  TV-MA     93 min
# 2             2011      R     78 min
# 3             2009  PG-13     80 min
# 4             2008  PG-13    123 min
# ...            ...    ...        ...
# 7782          2005  TV-MA     99 min
# 7783          2015  TV-14    111 min
# 7784          2019  TV-MA     44 min
# 7785          2019  TV-PG   1 Season
# 7786          2019  TV-MA     90 min
#
#                                               listed_in  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 0     In a future where the elite inhabit an island ...
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# ...                                                 ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7785  Dessert wizard Adriano Zumbo looks for the nex...
# 7786  This documentary delves into the mystique behi...
#
# [7787 rows x 12 columns]

# %%
missing_director = data[data['director'].isna()]
countries = missing_director['country'].dropna().str.split(', ').explode()
top5 = countries.value_counts().head()
top5
# Out:
# country
# United States     874
# United Kingdom    249
# Japan             174
# South Korea       149
# Canada            128
# Name: count, dtype: int64

# %%
plt.figure(figsize=(10, 8))
plt.title("Top-5 Countries with Nan Values", fontweight='bold')
plt.xlabel("Country")
plt.ylabel("Number of movies")
plt.bar(top5.index, top5.values, color="mediumslateblue")
plt.xticks(rotation=45)
plt.grid(axis='y')
plt.show()

# %% [markdown]
# ### Задание 22 (0.5 балла)

# %% [markdown]
# Постройте pie chart (круговую диаграмму), показывающую 5 стран, в которых произвели больше всего фильмов.
#
# Добавьте на диаграмму:
#
# + Заголовок (Тип шрифта: ``family = 'monospace'``, насыщенность: ``fontweight='bold'``)
# + Название стран (Тип шрифта: ``family = 'monospace'``)
# + Подписи значений (%) (Тип шрифта: ``family = 'monospace'``)
# + Выберите стиль для диаграммы pastel c помощью библиотеки ``seaborn``
#
# ```colors = sns.color_palette('pastel')[0:5]```

# %%
films = data.query("type == 'Movie'").country.dropna()
films = films.str.split(', ').explode()
films_sorted = films.value_counts().head()
films_sorted
# Out:
# country
# United States     2430
# India              915
# United Kingdom     466
# Canada             286
# France             265
# Name: count, dtype: int64

# %%
sns.set_style("white")
colors = sns.color_palette('pastel')[0:5]
plt.figure(figsize=(7,7))

plt.pie(films_sorted.values, labels=films_sorted.index, colors=colors, autopct='%1.1f%%', textprops={'family': 'monospace'})
plt.title("Top 5 countries by number of films", fontfamily='monospace', fontweight='bold')

plt.show()

# %% [markdown]
# ### Задание 23 (0.5 балла)

# %% [markdown]
# Постройте subplots, где на первом графике будет круговая диаграмма, показывающая долю фильмов каждого рейтинга *(rating)*, а на втором столбчатая диаграмма, показывающая 3 страны, в которых было снято больше всего фильмов с рейтингом TV-MA.
#
# *Если фильмов в каких-то рейтингах меньше 50, то их в график брать не нужно*
#
# Добавьте на диаграммы:
#
# + Заголовки (можно жирным)
#
# Круговая диаграмма:
# + Подписи значений абсолютные
#
# Столбчатая диаграммма:
# + Сделайте так, чтобы ось Y была справа
# + Добавьте подпись «Количество фильмов» к оси Y и уберите подпись к оси X
# + Оставьте видимыми только правую и нижнюю границы

# %%
only_films = data.query("type == 'Movie'")
only_films
# Out:
#      show_id   type                                    title  \
# 1         s2  Movie                                     7:19
# 2         s3  Movie                                    23:59
# 3         s4  Movie                                        9
# 4         s5  Movie                                       21
# 6         s7  Movie                                      122
# ...      ...    ...                                      ...
# 7781   s7782  Movie                                     Zoom
# 7782   s7783  Movie                                     Zozo
# 7783   s7784  Movie                                   Zubaan
# 7784   s7785  Movie                        Zulu Man in Japan
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 6       Yasir Al Yasiri  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
# ...                 ...                                                ...
# 7781       Peter Hewitt  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                NaN                                            Nasty C
# 7786           Sam Dunn                                                NaN
#
#                                                 country          date_added  \
# 1                                                Mexico   December 23, 2016
# 2                                             Singapore   December 20, 2018
# 3                                         United States   November 16, 2017
# 4                                         United States     January 1, 2020
# 6                                                 Egypt        June 1, 2020
# ...                                                 ...                 ...
# 7781                                      United States    January 11, 2020
# 7782  Sweden, Czech Republic, United Kingdom, Denmar...    October 19, 2020
# 7783                                              India       March 2, 2019
# 7784                                                NaN  September 25, 2020
# 7786              United Kingdom, Canada, United States       March 1, 2020
#
#       release_year rating duration  \
# 1             2016  TV-MA   93 min
# 2             2011      R   78 min
# 3             2009  PG-13   80 min
# 4             2008  PG-13  123 min
# 6             2019  TV-MA   95 min
# ...            ...    ...      ...
# 7781          2006     PG   88 min
# 7782          2005  TV-MA   99 min
# 7783          2015  TV-14  111 min
# 7784          2019  TV-MA   44 min
# 7786          2019  TV-MA   90 min
#
#                                               listed_in  \
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# 6                   Horror Movies, International Movies
# ...                                                 ...
# 7781                 Children & Family Movies, Comedies
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7786                    Documentaries, Music & Musicals
#
#                                             description
# 1     After a devastating earthquake hits Mexico Cit...
# 2     When an army recruit is found dead, his fellow...
# 3     In a postapocalyptic world, rag-doll robots hi...
# 4     A brilliant group of students become card-coun...
# 6     After an awful accident, a couple admitted to ...
# ...                                                 ...
# 7781  Dragged from civilian life, a former superhero...
# 7782  When Lebanon's Civil War deprives Zozo of his ...
# 7783  A scrappy but poor boy worms his way into a ty...
# 7784  In this documentary, South African rapper Nast...
# 7786  This documentary delves into the mystique behi...
#
# [5377 rows x 12 columns]

# %%
rating_counts = only_films.groupby("rating").agg({"type" : "count"}).query("type > 50").sort_values(by="type", ascending=False)

# %%
TV_MA = only_films.query("rating == 'TV-MA'")
countries = TV_MA['country'].dropna().str.split(', ').explode()
top_countries = countries.value_counts().head(3)
top_countries
# Out:
# country
# United States     678
# India             218
# United Kingdom    126
# Name: count, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))
axes[0].pie(rating_counts["type"], labels=rating_counts.index,
autopct=lambda p: f'{int(p * sum(rating_counts["type"]) / 100)}')
axes[0].set_title("Доля фильмов по рейтингам", fontweight='bold')

axes[1].bar(top_countries.index, top_countries.values)

axes[1].set_title("Топ-3 стран по количеству фильмов TV-MA", fontweight='bold')

axes[1].yaxis.tick_right()
axes[1].yaxis.set_label_position("right")

axes[1].set_ylabel("Количество фильмов")
axes[1].set_xlabel("")

axes[1].spines['left'].set_visible(False)
axes[1].spines['top'].set_visible(False)

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Задание 24 (1 балл)
#
# Преобразуйте колонку `date_added` в datetime. Создайте новые столбцы month и year из преобразованного столбца. Постройте линейный график: сколько в среднем фильмов было снято в каждый из месяцев.
#
# Добавьте на график:
#
# + Заголовок жирным шрифтом
# + Подписи осей
# + Маркеры на точках перегиба
# + Настройте ось X: ось начинается с 1 заканчивается 12, шаг 1

# %%
only_films = data.query("type == 'Movie'").copy()
only_films['date_added'] = pd.to_datetime(only_films['date_added'])

only_films['month'] = only_films['date_added'].dt.month
only_films['year'] = only_films['date_added'].dt.year

only_films
# Out:
#      show_id   type                                    title  \
# 1         s2  Movie                                     7:19
# 2         s3  Movie                                    23:59
# 3         s4  Movie                                        9
# 4         s5  Movie                                       21
# 6         s7  Movie                                      122
# ...      ...    ...                                      ...
# 7781   s7782  Movie                                     Zoom
# 7782   s7783  Movie                                     Zozo
# 7783   s7784  Movie                                   Zubaan
# 7784   s7785  Movie                        Zulu Man in Japan
# 7786   s7787  Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# 6       Yasir Al Yasiri  Amina Khalil, Ahmed Dawood, Tarek Lotfy, Ahmed...
# ...                 ...                                                ...
# 7781       Peter Hewitt  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                NaN                                            Nasty C
# 7786           Sam Dunn                                                NaN
#
#                                                 country date_added  \
# 1                                                Mexico 2016-12-23
# 2                                             Singapore 2018-12-20
# 3                                         United States 2017-11-16
# 4                                         United States 2020-01-01
# 6                                                 Egypt 2020-06-01
# ...                                                 ...        ...
# 7781                                      United States 2020-01-11
# 7782  Sweden, Czech Republic, United Kingdom, Denmar... 2020-10-19
# 7783                                              India 2019-03-02
# 7784                                                NaN 2020-09-25
# 7786              United Kingdom, Canada, United States 2020-03-01
#
#       release_year rating duration  \
# 1             2016  TV-MA   93 min
# 2             2011      R   78 min
# 3             2009  PG-13   80 min
# 4             2008  PG-13  123 min
# 6             2019  TV-MA   95 min
# ...            ...    ...      ...
# 7781          2006     PG   88 min
# 7782          2005  TV-MA   99 min
# 7783          2015  TV-14  111 min
# 7784          2019  TV-MA   44 min
# 7786          2019  TV-MA   90 min
#
#                                               listed_in  \
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# 6                   Horror Movies, International Movies
# ...                                                 ...
# 7781                 Children & Family Movies, Comedies
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7786                    Documentaries, Music & Musicals
#
#                                             description    min  season  month  \
# 1     After a devastating earthquake hits Mexico Cit...   93.0     NaN     12
# 2     When an army recruit is found dead, his fellow...   78.0     NaN     12
# 3     In a postapocalyptic world, rag-doll robots hi...   80.0     NaN     11
# 4     A brilliant group of students become card-coun...  123.0     NaN      1
# 6     After an awful accident, a couple admitted to ...   95.0     NaN      6
# ...                                                 ...    ...     ...    ...
# 7781  Dragged from civilian life, a former superhero...   88.0     NaN      1
# 7782  When Lebanon's Civil War deprives Zozo of his ...   99.0     NaN     10
# 7783  A scrappy but poor boy worms his way into a ty...  111.0     NaN      3
# 7784  In this documentary, South African rapper Nast...   44.0     NaN      9
# 7786  This documentary delves into the mystique behi...   90.0     NaN      3
#
#       year
# 1     2016
# 2     2018
# 3     2017
# 4     2020
# 6     2020
# ...    ...
# 7781  2020
# 7782  2020
# 7783  2019
# 7784  2020
# 7786  2020
#
# [5377 rows x 16 columns]

# %%
monthly_avg = only_films.groupby(["year", "month"]).agg({"type" : "count"}).groupby('month').mean()
monthly_avg
# Out:
#             type
# month
# 1      62.222222
# 2      41.000000
# 3      78.500000
# 4      60.000000
# 5      46.375000
# 6      53.857143
# 7      57.571429
# 8      59.142857
# 9      46.111111
# 10     61.444444
# 11     46.454545
# 12     61.555556

# %%
plt.figure(figsize=(10, 6))

plt.plot(monthly_avg.index, monthly_avg['type'], marker='o', color="mediumseagreen")

plt.title("Среднее количество фильмов по месяцам", fontweight='bold')
plt.xlabel("Месяц")
plt.ylabel("Количество фильмов")

plt.xticks(range(1, 13))
plt.xlim(1, 12)

plt.grid(alpha=0.3)

plt.show()

# %% [markdown]
# ### Задание 25 (1 балл)

# %% [markdown]
# Постройте линеный график, в какие годы (столбец year, который вы создали в задании 4) сколько фильмов было снято.
#
# Добавьте на график:
#
# + Заголовок жирным шрифтом
# + Подписи осей
# + Измените цвет линии графика и сделайте ее пунктиром
# + Решетку на фон

# %%
year_counts = only_films.groupby('year').agg({"type" : "count"})

# %%
plt.figure(figsize=(10, 6))
plt.plot(year_counts.index, year_counts['type'], linestyle='--', color='orangered')

plt.title("Количество фильмов по годам", fontweight='bold')
plt.xlabel("Год")
plt.ylabel("Количество фильмов")

plt.grid(True, alpha=0.3)

plt.show()

# %% [markdown]
# ### Задание 26 (1 балл)

# %% [markdown]
# Будем работать со столбцом duration. Одни данные даны в минутах (для фильмов (Movie)), а другие в сезонах (для сериалов (TV shows)). Создайте два новых столбца min (для тех, у кого продолжительность в минутах) и season (для тех, у кого продолжительность в сезонах), в которых будут извлечены данные из столбца duration.
#
# Постройте subplots, где на первом графике гистрограмма распределения продолжительности фильмов, а на втором – гистрограмма распределения продолжительности сериалов.
#
# Добавьте на графики:
#
# + Заголовки жирным шрифтом
# + Подписи осей

# %%
data
# Out:
#      show_id     type                                    title  \
# 0         s1  TV Show                                       3%
# 1         s2    Movie                                     7:19
# 2         s3    Movie                                    23:59
# 3         s4    Movie                                        9
# 4         s5    Movie                                       21
# ...      ...      ...                                      ...
# 7782   s7783    Movie                                     Zozo
# 7783   s7784    Movie                                   Zubaan
# 7784   s7785    Movie                        Zulu Man in Japan
# 7785   s7786  TV Show                    Zumbo's Just Desserts
# 7786   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#                director                                               cast  \
# 0                   NaN  João Miguel, Bianca Comparato, Michel Gomes, R...
# 1     Jorge Michel Grau  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...
# 2          Gilbert Chan  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...
# 3           Shane Acker  Elijah Wood, John C. Reilly, Jennifer Connelly...
# 4        Robert Luketic  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...
# ...                 ...                                                ...
# 7782        Josef Fares  Imad Creidi, Antoinette Turk, Elias Gergi, Car...
# 7783        Mozez Singh  Vicky Kaushal, Sarah-Jane Dias, Raaghav Chanan...
# 7784                NaN                                            Nasty C
# 7785                NaN                         Adriano Zumbo, Rachel Khoo
# 7786           Sam Dunn                                                NaN
#
#                                                 country date_added  \
# 0                                                Brazil 2020-08-14
# 1                                                Mexico 2016-12-23
# 2                                             Singapore 2018-12-20
# 3                                         United States 2017-11-16
# 4                                         United States 2020-01-01
# ...                                                 ...        ...
# 7782  Sweden, Czech Republic, United Kingdom, Denmar... 2020-10-19
# 7783                                              India 2019-03-02
# 7784                                                NaN 2020-09-25
# 7785                                          Australia 2020-10-31
# 7786              United Kingdom, Canada, United States 2020-03-01
#
#       release_year rating   duration  \
# 0             2020  TV-MA  4 Seasons
# 1             2016  TV-MA     93 min
# 2             2011      R     78 min
# 3             2009  PG-13     80 min
# 4             2008  PG-13    123 min
# ...            ...    ...        ...
# 7782          2005  TV-MA     99 min
# 7783          2015  TV-14    111 min
# 7784          2019  TV-MA     44 min
# 7785          2019  TV-PG   1 Season
# 7786          2019  TV-MA     90 min
#
#                                               listed_in  \
# 0     International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                          Dramas, International Movies
# 2                   Horror Movies, International Movies
# 3     Action & Adventure, Independent Movies, Sci-Fi...
# 4                                                Dramas
# ...                                                 ...
# 7782                       Dramas, International Movies
# 7783     Dramas, International Movies, Music & Musicals
# 7784  Documentaries, International Movies, Music & M...
# 7785                 International TV Shows, Reality TV
# 7786                    Documentaries, Music & Musicals
#
#                                             description  month    year    min  \
# 0     In a future where the elite inhabit an island ...    8.0  2020.0    NaN
# 1     After a devastating earthquake hits Mexico Cit...   12.0  2016.0   93.0
# 2     When an army recruit is found dead, his fellow...   12.0  2018.0   78.0
# 3     In a postapocalyptic world, rag-doll robots hi...   11.0  2017.0   80.0
# 4     A brilliant group of students become card-coun...    1.0  2020.0  123.0
# ...                                                 ...    ...     ...    ...
# 7782  When Lebanon's Civil War deprives Zozo of his ...   10.0  2020.0   99.0
# 7783  A scrappy but poor boy worms his way into a ty...    3.0  2019.0  111.0
# 7784  In this documentary, South African rapper Nast...    9.0  2020.0   44.0
# 7785  Dessert wizard Adriano Zumbo looks for the nex...   10.0  2020.0    NaN
# 7786  This documentary delves into the mystique behi...    3.0  2020.0   90.0
#
#       season
# 0        4.0
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# ...      ...
# 7782     NaN
# 7783     NaN
# 7784     NaN
# 7785     1.0
# 7786     NaN
#
# [7787 rows x 16 columns]

# %%
data['min'] = data['duration'].where(data['type'] == 'Movie').str.extract(r'(\d+)').astype(float)
data['season'] = data['duration'].where(data['type'] == 'TV Show').str.extract(r'(\d+)').astype(float)

# %%
fig, axes = plt.subplots(1, 2, figsize=(14, 6))

axes[0].hist(data['min'].dropna(),bins=30, color='mediumaquamarine')

axes[0].set_title("Распределение длительности фильмов", fontweight='bold')
axes[0].set_xlabel("Минуты")
axes[0].set_ylabel("Количество")

axes[1].hist(data['season'].dropna(), bins=20, color='crimson')

axes[1].set_title("Распределение количества сезонов", fontweight='bold')
axes[1].set_xlabel("Сезоны")
axes[1].set_ylabel("Количество")

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Задание 27 (0.5 балла)

# %% [markdown]
# Постройте ящик с усами (box plot) по продолжительности фильмов (Movies). Визуально проинтерпретируйте его.

# %%
plt.figure(figsize=(8, 5))

plt.boxplot(data['min'].dropna())

plt.title("Распределение длительности фильмов", fontweight='bold')
plt.ylabel("Минуты")

plt.show()

# %% [markdown]
# **ВАШ ОТВЕТ**
# Медианная длительность фильмов составляет около 100 минут. БОльшая часть фильмов лежит в диапазоне примерно от 85 до 110 минут. Много выбросов в сторону увеличение длительности, распределение смещено вправо

# %% [markdown]
# ### Задание 28 (1 балл)

# %% [markdown]
# Постройте при помощи библиотеки plotly интерактивную столбчатую диаграмму, которая сравнивает среднюю продолжительность фильмов и сериалов за каждый год, начиная с 2000.

# %%
import plotly.express as px
data['date_added'] = pd.to_datetime(data['date_added'])
data['year'] = data['date_added'].dt.year
df_2000 = data[data['year'] >= 2000]
movies = df_2000[df_2000['type'] == 'Movie'].groupby('year')['min'].mean().reset_index()
movies['type'] = 'Movie'
shows = df_2000[df_2000['type'] == 'TV Show'].groupby('year')['season'].mean().reset_index()
shows['type'] = 'TV Show'
final_df = pd.concat([movies, shows], ignore_index=True)
final_df['value'] = final_df['min'].fillna(final_df['season'])

# %%
interactive = px.bar(final_df, x='year', y='value', color='type', barmode='group', title='Средняя продолжительность фильмов и сериалов по годам')

interactive.update_layout(xaxis_title='Год', yaxis_title='Средняя продолжительность')

interactive.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="87ac3d7a-9199-41f9-8838-f6f5ec37a6d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87ac3d7a-9199-41f9-8838-f6f5ec37a6d8")) {                    Plotly.newPlot(                        "87ac3d7a-9199-41f9-8838-f6f5ec37a6d8",                        [{"alignmentgroup":"True","hovertemplate":"type=Movie\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Movie","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Movie","offsetgroup":"Movie","orientation":"v","showlegend":true,"textposition":"auto","x":[2008.0,2009.0,2010.0,2011.0,2012.0,2013.0,2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0],"xaxis":"x","y":[81.0,66.5,84.0,93.46153846153847,62.0,83.5,77.0,82.75862068965517,83.87984496124031,95.83333333333333,101.7195219123506,100.52304609218437,101.76600609756098,107.01136363636364],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"type=TV Show\u003cbr\u003eyear=%{x}\u003cbr\u003evalue=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"TV Show","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"TV Show","offsetgroup":"TV Show","orientation":"v","showlegend":true,"textposition":"auto","x":[2008.0,2013.0,2014.0,2015.0,2016.0,2017.0,2018.0,2019.0,2020.0,2021.0],"xaxis":"x","y":[1.0,2.75,4.6,2.142857142857143,1.3045977011494252,1.5578635014836795,1.5911330049261083,1.6103286384976525,1.9367816091954022,1.896551724137931],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.22222222 ...

# %% [markdown]
# ## Заключительная часть

# %% [markdown]
# Надеемся, вы честно проделали все пункты, а не просто пролистали досюда. Теперь можно отдохнуть и похвалить себя. Но пожалуйста, не стоит награждать себя до того, как закончите работать над домашкой :)

# %% [markdown]
# Поделитесь впечатлениями о задании:
# С удовольствием провел время с документацией! Спасибо! Домашка 10/10

# %% [markdown]
# P.S Удачного кодинга!
# Пейте черничный латте, пишите красивый Python!!
